# %%
import pandas as pd

# %%
df = pd.read_csv('/content/iran protests.csv')

# %%
df.head()
# Out:
#         Date  Death Toll of Protestors  Number of Children Killed  \
# 0  9/17/2022                         0                          0
# 1  9/18/2022                         0                          0
# 2  9/19/2022                         8                          0
# 3  9/20/2022                        28                          1
# 4  9/21/2022                        74                          8
#
#    Number of Military-Security Personnel Killed  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             9
#
#    Number of Individuals Arrested  Number of Detainees Identified  \
# 0                              78                              13
# 1                             255                              29
# 2                             527                              58
# ...

# %%
df.tail()
# Out:
#            Date  Death Toll of Protestors  Number of Children Killed  \
# 105  12/31/2022                       511                         69
# 106  01-01-2023                       512                         69
# 107  01-02-2023                       516                         70
# 108  01-03-2023                       516                         70
# 109  01-04-2023                       516                         70
#
#      Number of Military-Security Personnel Killed  \
# 105                                            66
# 106                                            67
# 107                                            67
# 108                                            68
# 109                                            68
#
#      Number of Individuals Arrested  Number of Detainees Identified  \
# 105                           19202                            4392
# 106                           19204                            4465
# ...

# %%
df.shape
# Out:
# (110, 10)

# %%
df.columns
# Out:
# Index(['Date', 'Death Toll of Protestors', 'Number of Children Killed',
#        'Number of Military-Security Personnel Killed',
#        'Number of Individuals Arrested', 'Number of Detainees Identified',
#        'Number of Students Arrested', 'Number of Protests',
#        'Number of Cities Involved', 'Number of Universities Involved'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Date                                            0
# Death Toll of Protestors                        0
# Number of Children Killed                       0
# Number of Military-Security Personnel Killed    0
# Number of Individuals Arrested                  0
# Number of Detainees Identified                  0
# Number of Students Arrested                     0
# Number of Protests                              0
# Number of Cities Involved                       0
# Number of Universities Involved                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 10 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Date                                          110 non-null    object
#  1   Death Toll of Protestors                      110 non-null    int64
#  2   Number of Children Killed                     110 non-null    int64
#  3   Number of Military-Security Personnel Killed  110 non-null    int64
#  4   Number of Individuals Arrested                110 non-null    int64
#  5   Number of Detainees Identified                110 non-null    int64
#  6   Number of Students Arrested                   110 non-null    int64
#  7   Number of Protests                            110 non-null    int64
#  8   Number of Cities Involved                     110 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Death Toll of Protestors  Number of Children Killed  \
# count                110.000000                 110.000000
# mean                 339.990909                  48.090909
# std                  143.274452                  19.836740
# min                    0.000000                   0.000000
# 25%                  243.000000                  36.000000
# 50%                  333.000000                  51.000000
# 75%                  477.250000                  66.500000
# max                  516.000000                  70.000000
#
#        Number of Military-Security Personnel Killed  \
# count                                    110.000000
# mean                                      41.490909
# std                                       20.444934
# min                                        0.000000
# 25%                                       26.000000
# 50%                                       39.000000
# 75%                                       61.000000
# ...

# %%
df.nunique()
# Out:
# Date                                            110
# Death Toll of Protestors                         81
# Number of Children Killed                        38
# Number of Military-Security Personnel Killed     35
# Number of Individuals Arrested                   90
# Number of Detainees Identified                  109
# Number of Students Arrested                      99
# Number of Protests                               94
# Number of Cities Involved                        43
# Number of Universities Involved                  44
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index(['Date'])

# %%
df
# Out:
#             Death Toll of Protestors  Number of Children Killed  \
# Date
# 2022-09-17                         0                          0
# 2022-09-18                         0                          0
# 2022-09-19                         8                          0
# 2022-09-20                        28                          1
# 2022-09-21                        74                          8
# ...                              ...                        ...
# 2022-12-31                       511                         69
# 2023-01-01                       512                         69
# 2023-01-02                       516                         70
# 2023-01-03                       516                         70
# 2023-01-04                       516                         70
#
#             Number of Military-Security Personnel Killed  \
# Date
# 2022-09-17                                             0
# 2022-09-18                                             0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=df['Death Toll of Protestors'])
sns.lineplot(data=df['Number of Children Killed'])
sns.lineplot(data=df['Number of Military-Security Personnel Killed'])
plt.show()

# %%
import plotly.express as px
fig = px.line(df, x = df.index, y="Death Toll of Protestors", title='Death Toll of Protestor')
fig1 = px.line(df, x = df.index, y="Number of Children Killed", title='Number of Children Killed')
fig2 = px.line(df, x = df.index, y="Number of Military-Security Personnel Killed", title = 'date')
fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Death Toll of Protestors", text_auto=True,
 title='Death Toll of Protestors')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Children Killed", text_auto=True,
 title='Number of Children Killed')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Military-Security Personnel Killed",
 title='Number of Military-Security Personnel Killed')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=df['Number of Individuals Arrested'])
sns.lineplot(data=df['Number of Detainees Identified'])
sns.lineplot(data=df['Number of Students Arrested'])
plt.show()

# %%
fig = px.line(df, x = df.index, y="Number of Individuals Arrested", title="Number of Individuals arrested")
fig1 = px.line(df, x = df.index, y="Number of Detainees Identified", title = "Number of Detainees Identified")
fig2 = px.line(df, x = df.index, y="Number of Students Arrested", title = "Number of Students Arrested")
fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Individuals Arrested", text_auto=True,
 title='Number of Individuals Arrested')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Detainees Identified", text_auto=True,
 title='Number of Detainees Identified')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Students Arrested", text_auto=True,
 title='Number of Students Arrested')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize = (14,6))
sns.lineplot(data=df['Number of Protests'])
sns.lineplot(data=df['Number of Cities Involved'])
sns.lineplot(data=df['Number of Universities Involved'])
plt.show()

# %%
fig = px.line(df, x = df.index, y="Number of Protests", title='Number of Protests')
fig1 = px.line(df, x = df.index, y="Number of Cities Involved", title = "Number of Cities Involved")
fig2 = px.line(df, x = df.index, y="Number of Universities Involved", title = "Number of Universities Involved")
fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Protests", text_auto=True,
 title='Number of Protests')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Cities Involved", text_auto=True,
 title='Number of Cities Involved')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x= df.index, y = "Number of Universities Involved", text_auto=True,
 title='Number of Universities Involved')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cor = df.corr()
cor
# Out:
#                                               Death Toll of Protestors  \
# Death Toll of Protestors                                      1.000000
# Number of Children Killed                                     0.990650
# Number of Military-Security Personnel Killed                  0.992470
# Number of Individuals Arrested                                0.937188
# Number of Detainees Identified                                0.965407
# Number of Students Arrested                                   0.978294
# Number of Protests                                            0.977017
# Number of Cities Involved                                     0.946996
# Number of Universities Involved                               0.923991
#
#                                               Number of Children Killed  \
# Death Toll of Protestors                                       0.990650
# Number of Children Killed                                      1.000000
# ...

# %%
plt.figure(figsize = (14,6))
sns.heatmap(cor, annot = True)
plt.show()
